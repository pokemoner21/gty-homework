# %%
import warnings
warnings.filterwarnings("ignore")
from __future__ import print_function
import pandas as pd
import numpy as np
from scipy import  stats
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.graphics.api import qqplot

# %%
dta=[270232.3,319515.5,349081.4,413030.3,489300.6,540367.4,595244.4,643974,689052.1,743585.5,827122]

# %%
#此处将数据备份一份，随后会将数据修改，需要保留一份源数据
dta0=pd.Series(dta[:],index=sm.tsa.datetools.dates_from_range('2007','2017'))

# %%
#即数据长度
len(dta)
# Out:
# 11

# %%
#使用pandas.Series容器封装数据，相比List，Series添加了时间索引，更适用于时间序列预测
dta=pd.Series(dta) 
#为数据添加时间索引
dta.index = pd.Index(sm.tsa.datetools.dates_from_range('2007','2017'))
#绘图，观察数据趋势
dta.plot(figsize=(12,8))
