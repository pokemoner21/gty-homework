# %%
#第一题
for i in range (1,6):
    for k in range(1,6):
        for j in range(1,6):
            for l in range (1,6):
                if l!=4 and i!=4 and k!=4 and j!=4 and i!=k and i!=j and i!=l and k!=j and k!=l and j!=l:
                    print(i,j,k,l)
            
                    

#第二题    
mylist=[]
for count in range (20):
    mylist.append(0)
mylist[0]=1
mylist[1]=1
for i in range (2,20,1):
    mylist[i]=mylist[i-1]+mylist[i-2]

for k in range(0,19):
    t=mylist[k]+mylist[k+1]
print(t)



#第三题


h = 0
leap = 1
from math import sqrt
from sys import stdout
for m in range(2,201):
    k = int(sqrt(m + 1))
    for i in range(2,k + 1):
        if m % i == 0:
            leap = 0
            break
    if leap == 1 and (m//100+(m%100)//10+(m%100)%10)%2==0:
        print( '%-4d' % m)
        h += 1
    leap = 1
    
    
#第四题
t=a(range(10))
b=0
for j in range(1,5)
    t[b]=(350*(2*j-1)/150)
    b+=1
    t[b]=(50*(2*j-1)/50)
    b+=1

print(t)
# Out:
# 1 3 2 5
# 1 5 2 3
# 1 2 3 5
# 1 5 3 2
# 1 2 5 3
# 1 3 5 2
# 2 3 1 5
# 2 5 1 3
# 2 1 3 5
# 2 5 3 1
# 2 1 5 3
# 2 3 5 1
# 3 2 1 5
# 3 5 1 2
# 3 1 2 5
# 3 5 2 1
# 3 1 5 2
# 3 2 5 1
# 5 2 1 3
# 5 3 1 2
# 5 1 2 3
# 5 3 2 1
# 5 1 3 2
# 5 2 3 1
# 10946
# 2
# 11
# 13
# 17
# 19
# 31
# 37
# 53
# 59
# 71
# 73
# 79
# 97
# 101
# 103
# 107
# 109
# 127
# 149
# 163
# 167
# 181
